# %%
from sklearn.datasets import fetch_20newsgroups

import torch
from gensim import corpora, models
from gensim.utils import simple_preprocess

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, v_measure_score, homogeneity_score

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
import numpy as np
import pandas as pd
import random

# %%
folder = "./20news_lda_lsi/"
kmeans_res_path = "kmeans_res_20News_"
hierarchy_res_path = "hierarchy_res_20News_"


categories_light = ["comp.graphics", "rec.autos", "sci.med",  "talk.politics.mideast"]
categories_hard = ["talk.politics.guns", "talk.politics.mideast",  "talk.politics.misc"]
categories = {"light": categories_light, "hard": categories_hard}

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)
    
    tokens = [word.lower() for word in tokens if word.isalnum()]
    
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words ]
    
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# %%
def filter_text_by_pos(text, pos_to_keep):
    tokens = word_tokenize(text)
    tagged_tokens = pos_tag(tokens)
    
    filtered_tokens = [token for token, pos in tagged_tokens if pos in pos_to_keep]
    
    return filtered_tokens

# %%
def cluster_kmeans(matrix, metrics, true_labels, num_clusters=2, num_iterations=50):
    scores = {}
    for metric in metrics:
        scores.update({metric.__name__: []})

    for i in range(num_iterations):
        clusters = KMeans(n_clusters=num_clusters, random_state=i, n_init=10)

        clusters.fit_predict(matrix)
        
        for metric in metrics:
            score = metric(true_labels, clusters.labels_)
            scores[metric.__name__].append(score)

    kmeans_res = ""
    for metric in scores:
        kmeans_res += f"\n{metric} \nMax: {np.max(scores[metric])} \
                                    \nMin: {np.min(scores[metric])} \
                                    \nAVG: {np.mean(scores[metric])} \n"
        
    print(kmeans_res)
    return kmeans_res

# %%
def cluster_hierarchy(matrix, metrics, true_labels, num_clusters=2):
    linkages = ["complete", "average", "single"]

    hierarchy_res = ""

    if matrix.shape[0] != matrix.shape[1]:
        affinity = "euclidean"
        # matrix = matrix.toarray()
        linkages.append("ward")
    else:
        affinity = "precomputed"

    for linkage in linkages:
        hierarchy_res += f"\n{linkage}"

        agg_clustering = AgglomerativeClustering(n_clusters=num_clusters, metric=affinity, linkage=linkage)

        agg_clustering.fit_predict(matrix)

        for metric in metrics:
            score = metric(true_labels, agg_clustering.labels_)
            hierarchy_res += f"\n{metric.__name__}: {score}"
        
        hierarchy_res += "\n"
    
    print(hierarchy_res)
    return hierarchy_res

# %%
def main(dataset):
    num_topics = 10
    true_labels = dataset.target
    distances = ["none", "euclidean", "cosine"]
    metrics = [normalized_mutual_info_score, adjusted_rand_score, v_measure_score, homogeneity_score]

    kmeans_data = pd.DataFrame(columns=distances)
    hierarchy_data = pd.DataFrame(columns=distances)

    preprocessed_data = [preprocess_text(text) for text in dataset.data]
    n = len(preprocessed_data)
    print(n)

    noun_data = [filter_text_by_pos(text, pos_to_keep=['NN', 'NNS']) for text in preprocessed_data]
    adj_data = [filter_text_by_pos(text, pos_to_keep=['JJ', 'JJR', 'JJS']) for text in preprocessed_data]
    noun_adj_data = [filter_text_by_pos(text, pos_to_keep=['NN', 'NNS', 'JJ', 'JJR', 'JJS']) for text in preprocessed_data]

    preprocessed_data = [text.split(' ') for text in preprocessed_data]
    list_of_data = {"ALL": preprocessed_data, "NOUNS": noun_data, "ADJ": adj_data, "NOUNS and ADJ": noun_adj_data}

    for name, data in list_of_data.items():
        print("start calculate " + name)
        text_vectors = []

        dictionary = corpora.Dictionary(data)

        bow_corpus = [dictionary.doc2bow(doc) for doc in data]

        model = models.LsiModel(bow_corpus, id2word=dictionary, num_topics=num_topics)

        for doc_bow in bow_corpus:
            document_topics = model[doc_bow]
            document_topic_vector = [float(topic_prob) for _, topic_prob in document_topics]
            if document_topic_vector == [] or len(document_topic_vector) < num_topics:
                document_topic_vector = [random.uniform(-0.00001, 0.00001) for _ in range(num_topics)]
            text_vectors.append(document_topic_vector)

        for distance in distances:
            print(distance)
            if distance == "euclidean":
                distance_matrix = euclidean_distances(text_vectors)
            elif distance == "cosine":
                distance_matrix = cosine_distances(text_vectors)
            elif distance == "none":
                distance_matrix = np.array(text_vectors)

            print(distance_matrix.shape)

            kmeans_data.loc[name, distance] = cluster_kmeans(distance_matrix, metrics, true_labels, num_clusters=len(dataset.target_names))

            hierarchy_data.loc[name, distance] = cluster_hierarchy(distance_matrix, metrics, true_labels, num_clusters=len(dataset.target_names))

    return kmeans_data, hierarchy_data

# %%
news_data = {}
for category in categories:
    newsgroups = fetch_20newsgroups(subset="train",
                                remove=("headers", "footers", "quotes"),
                                categories=categories[category])
    news_data.update({category: newsgroups})

# %%
name_data = [key for key in news_data][0]
name_data
# Out:
# 'light'

# %%
for data in news_data:
    print(data)
    kmeans_data, hierarchy_data = main(news_data[data])
    
    print("Saved")
    kmeans_data.to_excel(folder + "lsi" + "/" + kmeans_res_path + data + ".xlsx")
    hierarchy_data.to_excel(folder + "lsi" + "/" + hierarchy_res_path + data + ".xlsx")
# Out:
# light
# 2336
# start calculate ALL
# none
# (2336, 10)
#
# normalized_mutual_info_score
# Max: 0.007666133223518858
# Min: 0.00681646869276016
# AVG: 0.007615153351673336
#
# adjusted_rand_score
# Max: 0.00011699278835083276
# Min: 9.21218674679546e-05
# AVG: 0.00011550053309786003
#
# v_measure_score
# Max: 0.007666133223518859
# Min: 0.006816468692760161
# AVG: 0.007615153351673336
#
# homogeneity_score
# Max: 0.003912910104408967
# Min: 0.0034726490801218887
# AVG: 0.0038864944429517424
#
#
# complete
# normalized_mutual_info_score: 0.007666133223518858
# adjusted_rand_score: 0.00011699278835083276
# v_measure_score: 0.007666133223518859
# homogeneity_score: 0.003912910104408967
#
# average
# normalized_mutual_info_score: 0.0033962876235603748
# adjusted_rand_score: 6.151642592861362e-06
# v_measure_score: 0.003396287623560374
# homogeneity_score: 0.0017157841815314226
#
# single
# normalized_mutual_info_score: 0.0033962876235603748
# adjusted_rand_score: 6.151642592861362e-06
# v_measure_score: 0.003396287623560374
# homogeneity_score: 0.0017157841815314226
#
# ward
# normalized_mutual_info_score: 0.007666133223518858
# adjusted_rand_score: 0.00011699278835083276
# v_measure_score: 0.007666133223518859
# homogeneity_score: 0.003912910104408967
#
# euclidean
# (2336, 2336)
#
# normalized_mutual_info_score
# Max: 0.018709348589622025
# Min: 0.013877974766754522
# AVG: 0.016438106559351896
#
# adjusted_rand_score
# Max: 0.001507153392320582
# Min: 0.001168929349725676
# AVG: 0.0013072998985160988
#
# v_measure_score
# Max: 0.01870934858962203
# Min: 0.013877974766754522
# AVG: 0.016438106559351896
#
# homogeneity_score
# Max: 0.010386728332658099
# Min: 0.007630546164690031
# AVG: 0.009083815157866602
#
#
# complete
# normalized_mutual_info_score: 0.007666133223518858
# adjusted_rand_score: 0.00011699278835083276
# v_measure_score: 0.007666133223518859
# homogeneity_score: 0.003912910104408967
#
# average
# normalized_mutual_info_score: 0.0033962876235603748
# adjusted_rand_score: 6.151642592861362e-06
# v_measure_score: 0.003396287623560374
# homogeneity_score: 0.0017157841815314226
#
# single
# normalized_mutual_info_score: 0.0033962876235603748
# adjusted_rand_score: 6.151642592861362e-06
# v_measure_score: 0.003396287623560374
# homogeneity_score: 0.0017157841815314226
#
# cosine
# (2336, 2336)
#
# normalized_mutual_info_score
# Max: 0.08651153214247104
# Min: 0.08506123337250159
# AVG: 0.08602302278254303
#
# adjusted_rand_score
# Max: 0.06808309155474587
# Min: 0.06727696927281836
# AVG: 0.06765176930062834
#
# v_measure_score
# Max: 0.08651153214247104
# Min: 0.08506123337250157
# AVG: 0.08602302278254303
#
# homogeneity_score
# Max: 0.07610748469748742
# Min: 0.07494000813747775
# AVG: 0.07574775302201668
#
#
# complete
# normalized_mutual_info_score: 0.048571507414598765
# adjusted_rand_score: 0.02061431626255055
# v_measure_score: 0.04857150741459876
# homogeneity_score: 0.035093475571438416
#
# average
# normalized_mutual_info_score: 0.004269277599374052
# adjusted_rand_score: -3.9899922702104045e-05
# v_measure_score: 0.004269277599374053
# homogeneity_score: 0.002444149617934818
#
# single
# normalized_mutual_info_score: 0.003931541647414835
# adjusted_rand_score: 4.280016169535686e-06
# v_measure_score: 0.003931541647414835
# homogeneity_score: 0.0021879700565961393
#
# start calculate NOUNS
# none
# (2336, 10)
#
# normalized_mutual_info_score
# Max: 0.00681646869276016
# Min: 0.00681646869276016
# AVG: 0.006816468692760159
#
# adjusted_rand_score
# Max: 9.21218674679546e-05
# Min: 9.21218674679546e-05
# AVG: 9.212186746795461e-05
#
# v_measure_score
# Max: 0.006816468692760161
# Min: 0.006816468692760161
# AVG: 0.00681646869276016
#
# homogeneity_score
# Max: 0.0034726490801218887
# Min: 0.0034726490801218887
# AVG: 0.0034726490801218883
#
#
# complete
# normalized_mutual_info_score: 0.00681646869276016
# adjusted_rand_score: 9.21218674679546e-05
# v_measure_score: 0.006816468692760161
# homogeneity_score: 0.0034726490801218887
#
# average
# normalized_mutual_info_score: 0.0033962876235603748
# adjusted_rand_score: 6.151642592861362e-06
# v_measure_score: 0.003396287623560374
# homogeneity_score: 0.0017157841815314226
#
# single
# normalized_mutual_info_score: 0.0033962876235603748
# adjusted_rand_score: 6.151642592861362e-06
# v_measure_score: 0.003396287623560374
# homogeneity_score: 0.0017157841815314226
#
# ward
# normalized_mutual_info_score: 0.006073021045587363
# adjusted_rand_score: 9.665633600925112e-06
# v_measure_score: 0.006073021045587363
# homogeneity_score: 0.0031054341967884343
#
# euclidean
# (2336, 2336)
#
# normalized_mutual_info_score
# Max: 0.009610186654244087
# Min: 0.0076542338562395175
# AVG: 0.007798162509898208
#
# adjusted_rand_score
# Max: 0.0006861363575722421
# Min: 0.0005649125927226276
# AVG: 0.000579282884932165
#
# v_measure_score
# Max: 0.009610186654244087
# Min: 0.007654233856239517
# AVG: 0.007798162509898208
#
# homogeneity_score
# Max: 0.005252503269448058
# Min: 0.004161815997734679
# AVG: 0.004242791559881529
#
#
# complete
# normalized_mutual_info_score: 0.00681646869276016
# adjusted_rand_score: 9.21218674679546e-05
# v_measure_score: 0.006816468692760161
# homogeneity_score: 0.0034726490801218887
#
# average
# normalized_mutual_info_score: 0.0033962876235603748
# adjusted_rand_score: 6.151642592861362e-06
# v_measure_score: 0.003396287623560374
# homogeneity_score: 0.0017157841815314226
#
# single
# normalized_mutual_info_score: 0.0033962876235603748
# adjusted_rand_score: 6.151642592861362e-06
# v_measure_score: 0.003396287623560374
# homogeneity_score: 0.0017157841815314226
#
# cosine
# (2336, 2336)
#
# normalized_mutual_info_score
# Max: 0.20639471910121457
# Min: 0.20583313796610916
# AVG: 0.20610144269012232
#
# adjusted_rand_score
# Max: 0.20429516319210375
# Min: 0.20365052639065973
# AVG: 0.20402491081740848
#
# v_measure_score
# Max: 0.20639471910121457
# Min: 0.2058331379661092
# AVG: 0.20610144269012232
#
# homogeneity_score
# Max: 0.20018858914167503
# Min: 0.19963439433289049
# AVG: 0.19990934474949154
#
#
# complete
# normalized_mutual_info_score: 0.024635350408756897
# adjusted_rand_score: 0.003068677422392651
# v_measure_score: 0.024635350408756897
# homogeneity_score: 0.01522213285426828
#
# average
# normalized_mutual_info_score: 0.00312114287666414
# adjusted_rand_score: 5.333708052537826e-06
# v_measure_score: 0.00312114287666414
# homogeneity_score: 0.0016880756376749049
#
# single
# normalized_mutual_info_score: 0.0025184226021324556
# adjusted_rand_score: -2.8375386878099952e-05
# v_measure_score: 0.0025184226021324556
# homogeneity_score: 0.0012694264440796018
#
# start calculate ADJ
# none
# (2336, 10)
#
# normalized_mutual_info_score
# Max: 0.028075369847963036
# Min: 0.009084426299563884
# AVG: 0.017932285109386298
#
# adjusted_rand_score
# Max: 0.0014508530419501903
# Min: 0.0004018553269042657
# AVG: 0.0005953075745980372
#
# v_measure_score
# Max: 0.028075369847963036
# Min: 0.009084426299563884
# AVG: 0.0179322851093863
#
# homogeneity_score
# Max: 0.015045009273316376
# Min: 0.00474144752339017
# AVG: 0.009389652656289871
#
#
# complete
# normalized_mutual_info_score: 0.004255547919207
# adjusted_rand_score: 2.6504255649025592e-05
# v_measure_score: 0.004255547919207
# homogeneity_score: 0.002154375371750587
#
# average
# normalized_mutual_info_score: 0.004255547919207
# adjusted_rand_score: 2.6504255649025592e-05
# v_measure_score: 0.004255547919207
# homogeneity_score: 0.002154375371750587
#
# single
# normalized_mutual_info_score: 0.0025710456639721586
# adjusted_rand_score: 2.0583453387782e-05
# v_measure_score: 0.0025710456639721586
# homogeneity_score: 0.001295951422933902
#
# ward
# normalized_mutual_info_score: 0.010909440006563508
# adjusted_rand_score: 0.0002390715999695723
# v_measure_score: 0.010909440006563508
# homogeneity_score: 0.0056632785449984915
#
# euclidean
# (2336, 2336)
#
# normalized_mutual_info_score
# Max: 0.04978231710746286
# Min: 0.04884283892295224
# AVG: 0.049707158852701994
#
# adjusted_rand_score
# Max: 0.0063179219687601
# Min: 0.006230525017130009
# AVG: 0.006237516773260416
#
# v_measure_score
# Max: 0.04978231710746286
# Min: 0.04884283892295225
# AVG: 0.049707158852701994
#
# homogeneity_score
# Max: 0.028939328956955845
# Min: 0.028356249743301257
# AVG: 0.028892682619863472
#
#
# complete
# normalized_mutual_info_score: 0.004255547919207
# adjusted_rand_score: 2.6504255649025592e-05
# v_measure_score: 0.004255547919207
# homogeneity_score: 0.002154375371750587
#
# average
# normalized_mutual_info_score: 0.004255547919207
# adjusted_rand_score: 2.6504255649025592e-05
# v_measure_score: 0.004255547919207
# homogeneity_score: 0.002154375371750587
#
# single
# normalized_mutual_info_score: 0.0025710456639721586
# adjusted_rand_score: 2.0583453387782e-05
# v_measure_score: 0.0025710456639721586
# homogeneity_score: 0.001295951422933902
#
# cosine
# (2336, 2336)
#
# normalized_mutual_info_score
# Max: 0.08443457132655476
# Min: 0.08379246808100586
# AVG: 0.08409194976046296
#
# adjusted_rand_score
# Max: 0.05504558029512688
# Min: 0.054581570496473636
# AVG: 0.05487491314197733
#
# v_measure_score
# Max: 0.08443457132655476
# Min: 0.08379246808100584
# AVG: 0.08409194976046296
#
# homogeneity_score
# Max: 0.07970762262783
# Min: 0.07914350795738767
# AVG: 0.07940744541884165
#
#
# complete
# normalized_mutual_info_score: 0.016979256997005556
# adjusted_rand_score: 0.0036275516720779733
# v_measure_score: 0.01697925699700556
# homogeneity_score: 0.012043505208208292
#
# average
# normalized_mutual_info_score: 0.003611554728672128
# adjusted_rand_score: -5.193785602087121e-05
# v_measure_score: 0.0036115547286721277
# homogeneity_score: 0.0020784704257098816
#
# single
# normalized_mutual_info_score: 0.002592452913033401
# adjusted_rand_score: 4.0166989494134776e-05
# v_measure_score: 0.002592452913033401
# homogeneity_score: 0.0013067418788448078
#
# start calculate NOUNS and ADJ
# none
# (2336, 10)
#
# normalized_mutual_info_score
# Max: 0.00681646869276016
# Min: 0.00681646869276016
# AVG: 0.006816468692760159
#
# adjusted_rand_score
# Max: 9.21218674679546e-05
# Min: 9.21218674679546e-05
# AVG: 9.212186746795461e-05
#
# v_measure_score
# Max: 0.006816468692760161
# Min: 0.006816468692760161
# AVG: 0.00681646869276016
#
# homogeneity_score
# Max: 0.0034726490801218887
# Min: 0.0034726490801218887
# AVG: 0.0034726490801218883
#
#
# complete
# normalized_mutual_info_score: 0.004255547919207
# adjusted_rand_score: 2.6504255649025592e-05
# v_measure_score: 0.004255547919207
# homogeneity_score: 0.002154375371750587
#
# average
# normalized_mutual_info_score: 0.0034144581613785876
# adjusted_rand_score: 2.2807160205029293e-05
# v_measure_score: 0.003414458161378588
# homogeneity_score: 0.0017249638284912775
#
# single
# normalized_mutual_info_score: 0.002551779512195324
# adjusted_rand_score: 2.958270892064497e-06
# v_measure_score: 0.0025517795121953236
# homogeneity_score: 0.0012862402003136568
#
# ward
# normalized_mutual_info_score: 0.00681646869276016
# adjusted_rand_score: 9.21218674679546e-05
# v_measure_score: 0.006816468692760161
# homogeneity_score: 0.0034726490801218887
#
# euclidean
# (2336, 2336)
#
# normalized_mutual_info_score
# Max: 0.01938399842967757
# Min: 0.016925116405882956
# AVG: 0.019014951239420007
#
# adjusted_rand_score
# Max: 0.0018198095721772692
# Min: 0.001522126076930352
# AVG: 0.0017750605068690922
#
# v_measure_score
# Max: 0.019383998429677574
# Min: 0.01692511640588296
# AVG: 0.019014951239420003
#
# homogeneity_score
# Max: 0.010755454622959612
# Min: 0.009352420276024764
# AVG: 0.010544841365023771
#
#
# complete
# normalized_mutual_info_score: 0.004255547919207
# adjusted_rand_score: 2.6504255649025592e-05
# v_measure_score: 0.004255547919207
# homogeneity_score: 0.002154375371750587
#
# average
# normalized_mutual_info_score: 0.0034144581613785876
# adjusted_rand_score: 2.2807160205029293e-05
# v_measure_score: 0.003414458161378588
# homogeneity_score: 0.0017249638284912775
#
# single
# normalized_mutual_info_score: 0.002551779512195324
# adjusted_rand_score: 2.958270892064497e-06
# v_measure_score: 0.0025517795121953236
# homogeneity_score: 0.0012862402003136568
#
# cosine
# (2336, 2336)
#
# normalized_mutual_info_score
# Max: 0.19500935593215618
# Min: 0.19309434612372023
# AVG: 0.19378718211590368
#
# adjusted_rand_score
# Max: 0.18388608527913008
# Min: 0.1823917025146377
# AVG: 0.18299379051188872
#
# v_measure_score
# Max: 0.19500935593215618
# Min: 0.19309434612372026
# AVG: 0.19378718211590368
#
# homogeneity_score
# Max: 0.18922393309368862
# Min: 0.1874074025005706
# AVG: 0.18806297824008425
#
#
# complete
# normalized_mutual_info_score: 0.08348770572995318
# adjusted_rand_score: 0.029780678443768773
# v_measure_score: 0.08348770572995318
# homogeneity_score: 0.05666179426533861
#
# average
# normalized_mutual_info_score: 0.006004063442148983
# adjusted_rand_score: 8.29724159193653e-05
# v_measure_score: 0.006004063442148984
# homogeneity_score: 0.003236195700285114
#
# single
# normalized_mutual_info_score: 0.0025440675528772575
# adjusted_rand_score: 2.7322461209621025e-07
# v_measure_score: 0.002544067552877258
# homogeneity_score: 0.0012852477021360728
#
# Saved
# hard
# 1575
# start calculate ALL
# none
# (1575, 10)
#
# normalized_mutual_info_score
# Max: 0.01255519116992239
# Min: 0.005696468796877703
# AVG: 0.006486355587232361
#
# adjusted_rand_score
# Max: 0.0007595957590600134
# Min: 0.0003160494303246203
# AVG: 0.00042893016595770217
#
# v_measure_score
# Max: 0.012555191169922392
# Min: 0.005696468796877704
# AVG: 0.006486355587232361
#
# homogeneity_score
# Max: 0.006523230059398401
# Min: 0.002953604672867333
# AVG: 0.00336161296861774
#
#
# complete
# normalized_mutual_info_score: 0.005384233438994563
# adjusted_rand_score: 0.00042847880278038285
# v_measure_score: 0.005384233438994563
# homogeneity_score: 0.002739167964223541
#
# average
# normalized_mutual_info_score: 0.005384233438994563
# adjusted_rand_score: 0.00042847880278038285
# v_measure_score: 0.005384233438994563
# homogeneity_score: 0.002739167964223541
#
# single
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
# ward
# normalized_mutual_info_score: 0.0051232151383395225
# adjusted_rand_score: 8.128443395906499e-07
# v_measure_score: 0.0051232151383395225
# homogeneity_score: 0.0026486273268964966
#
# euclidean
# (1575, 1575)
#
# normalized_mutual_info_score
# Max: 0.0025864724272706896
# Min: 0.0025864724272706896
# AVG: 0.00258647242727069
#
# adjusted_rand_score
# Max: 0.0005960806597738995
# Min: 0.0005960806597738995
# AVG: 0.0005960806597738995
#
# v_measure_score
# Max: 0.00258647242727069
# Min: 0.00258647242727069
# AVG: 0.00258647242727069
#
# homogeneity_score
# Max: 0.0013724471413703516
# Min: 0.0013724471413703516
# AVG: 0.0013724471413703511
#
#
# complete
# normalized_mutual_info_score: 0.005384233438994563
# adjusted_rand_score: 0.00042847880278038285
# v_measure_score: 0.005384233438994563
# homogeneity_score: 0.002739167964223541
#
# average
# normalized_mutual_info_score: 0.005384233438994563
# adjusted_rand_score: 0.00042847880278038285
# v_measure_score: 0.005384233438994563
# homogeneity_score: 0.002739167964223541
#
# single
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
# cosine
# (1575, 1575)
#
# normalized_mutual_info_score
# Max: 0.009076189790147692
# Min: 0.008662371314894607
# AVG: 0.009067913420642632
#
# adjusted_rand_score
# Max: 0.002859361685000453
# Min: 0.002781117037447528
# AVG: 0.002857796792049394
#
# v_measure_score
# Max: 0.009076189790147694
# Min: 0.008662371314894607
# AVG: 0.009067913420642632
#
# homogeneity_score
# Max: 0.007224920688622499
# Min: 0.006916608643900561
# AVG: 0.007218754447728062
#
#
# complete
# normalized_mutual_info_score: 0.01455938018741798
# adjusted_rand_score: 0.0006411048800171544
# v_measure_score: 0.01455938018741798
# homogeneity_score: 0.009563668540222184
#
# average
# normalized_mutual_info_score: 0.0014649328439124449
# adjusted_rand_score: 0.0004037779119417636
# v_measure_score: 0.0014649328439124447
# homogeneity_score: 0.0008119065785873032
#
# single
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
# start calculate NOUNS
# none
# (1575, 10)
#
# normalized_mutual_info_score
# Max: 0.008324097795092087
# Min: 0.0056537738303141976
# AVG: 0.007689272822766892
#
# adjusted_rand_score
# Max: 0.0009923469496998854
# Min: 0.0005923148618697927
# AVG: 0.0007755860155672858
#
# v_measure_score
# Max: 0.008324097795092087
# Min: 0.0056537738303141976
# AVG: 0.007689272822766892
#
# homogeneity_score
# Max: 0.004340413643846775
# Min: 0.0029560833093298924
# AVG: 0.0039561177119638614
#
#
# complete
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
# average
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# single
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
# ward
# normalized_mutual_info_score: 0.008121764294329755
# adjusted_rand_score: 0.0007595957590600134
# v_measure_score: 0.008121764294329757
# homogeneity_score: 0.004160027505136898
#
# euclidean
# (1575, 1575)
#
# normalized_mutual_info_score
# Max: 0.0033903806457212427
# Min: 0.0033903806457212427
# AVG: 0.003390380645721243
#
# adjusted_rand_score
# Max: 0.0006876661009832774
# Min: 0.0006876661009832774
# AVG: 0.0006876661009832776
#
# v_measure_score
# Max: 0.003390380645721243
# Min: 0.003390380645721243
# AVG: 0.003390380645721243
#
# homogeneity_score
# Max: 0.001793898841475749
# Min: 0.001793898841475749
# AVG: 0.0017938988414757493
#
#
# complete
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
# average
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# single
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
# cosine
# (1575, 1575)
#
# normalized_mutual_info_score
# Max: 0.0068176870705186346
# Min: 0.006642299377737338
# AVG: 0.006805169802286363
#
# adjusted_rand_score
# Max: 0.0050911148364500315
# Min: 0.004882776542309561
# AVG: 0.005074825787811354
#
# v_measure_score
# Max: 0.006817687070518635
# Min: 0.006642299377737338
# AVG: 0.006805169802286366
#
# homogeneity_score
# Max: 0.0064922662296579055
# Min: 0.006325855071693091
# AVG: 0.006480383189046963
#
#
# complete
# normalized_mutual_info_score: 0.0019700983137293333
# adjusted_rand_score: 0.00021289107937305757
# v_measure_score: 0.0019700983137293333
# homogeneity_score: 0.0010764159536270968
#
# average
# normalized_mutual_info_score: 0.003608063203627798
# adjusted_rand_score: 5.472741778333011e-05
# v_measure_score: 0.0036080632036277977
# homogeneity_score: 0.001957283498049633
#
# single
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
# start calculate ADJ
# none
# (1575, 10)
#
# normalized_mutual_info_score
# Max: 0.010247644346122036
# Min: 0.0025810389376197686
# AVG: 0.006729968906923996
#
# adjusted_rand_score
# Max: 0.00027565414853565444
# Min: -0.0004850171746590616
# AVG: 9.45970490862454e-05
#
# v_measure_score
# Max: 0.010247644346122037
# Min: 0.002581038937619769
# AVG: 0.006729968906923996
#
# homogeneity_score
# Max: 0.005454044602729581
# Min: 0.001303030803869079
# AVG: 0.003583296273439154
#
#
# complete
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
# average
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
# single
# normalized_mutual_info_score: 0.0028053801933154206
# adjusted_rand_score: 0.00031037410111617845
# v_measure_score: 0.0028053801933154206
# homogeneity_score: 0.0014162889041206329
#
# ward
# normalized_mutual_info_score: 0.004332912347294672
# adjusted_rand_score: 0.0008215753549859127
# v_measure_score: 0.004332912347294672
# homogeneity_score: 0.0022333423650610284
#
# euclidean
# (1575, 1575)
#
# normalized_mutual_info_score
# Max: 0.00632791142080587
# Min: 0.005102107894780497
# AVG: 0.0062543632092443464
#
# adjusted_rand_score
# Max: 8.249983547019074e-06
# Min: -0.00010637012146666007
# AVG: -9.949291516583933e-05
#
# v_measure_score
# Max: 0.006327911420805871
# Min: 0.005102107894780498
# AVG: 0.006254363209244348
#
# homogeneity_score
# Max: 0.0034352065873625923
# Min: 0.0027571749889900104
# AVG: 0.003394524691460238
#
#
# complete
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
# average
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
# single
# normalized_mutual_info_score: 0.0028053801933154206
# adjusted_rand_score: 0.00031037410111617845
# v_measure_score: 0.0028053801933154206
# homogeneity_score: 0.0014162889041206329
#
# cosine
# (1575, 1575)
#
# normalized_mutual_info_score
# Max: 0.08801732816300982
# Min: 0.08477752892190646
# AVG: 0.08683867255685648
#
# adjusted_rand_score
# Max: 0.06903984930964777
# Min: 0.06580073109081104
# AVG: 0.06634436344364791
#
# v_measure_score
# Max: 0.0880173281630098
# Min: 0.08477752892190644
# AVG: 0.08683867255685646
#
# homogeneity_score
# Max: 0.08213460650918673
# Min: 0.07947005994008569
# AVG: 0.08092398461858501
#
#
# complete
# normalized_mutual_info_score: 0.0021989201774923815
# adjusted_rand_score: 0.0012347137565860095
# v_measure_score: 0.0021989201774923815
# homogeneity_score: 0.001456363596346004
#
# average
# normalized_mutual_info_score: 0.0013403349365994854
# adjusted_rand_score: 0.0005599521727063518
# v_measure_score: 0.0013403349365994851
# homogeneity_score: 0.0007329754806993759
#
# single
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
# start calculate NOUNS and ADJ
# none
# (1575, 10)
#
# normalized_mutual_info_score
# Max: 0.008324097795092087
# Min: 0.006756293247239753
# AVG: 0.0073338377570328
#
# adjusted_rand_score
# Max: 0.0009923469496998854
# Min: 0.0005923148618697927
# AVG: 0.0006672278625024827
#
# v_measure_score
# Max: 0.008324097795092087
# Min: 0.006756293247239753
# AVG: 0.007333837757032802
#
# homogeneity_score
# Max: 0.004340413643846775
# Min: 0.0034491535814543017
# AVG: 0.0037513283521751896
#
#
# complete
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# average
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# single
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# ward
# normalized_mutual_info_score: 0.008121764294329755
# adjusted_rand_score: 0.0007595957590600134
# v_measure_score: 0.008121764294329757
# homogeneity_score: 0.004160027505136898
#
# euclidean
# (1575, 1575)
#
# normalized_mutual_info_score
# Max: 0.0033903806457212427
# Min: 0.0033903806457212427
# AVG: 0.003390380645721243
#
# adjusted_rand_score
# Max: 0.0006876661009832774
# Min: 0.0006876661009832774
# AVG: 0.0006876661009832776
#
# v_measure_score
# Max: 0.003390380645721243
# Min: 0.003390380645721243
# AVG: 0.003390380645721243
#
# homogeneity_score
# Max: 0.001793898841475749
# Min: 0.001793898841475749
# AVG: 0.0017938988414757493
#
#
# complete
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# average
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# single
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# cosine
# (1575, 1575)
#
# normalized_mutual_info_score
# Max: 0.0055042942992233005
# Min: 0.005254750862130764
# AVG: 0.005291797645836921
#
# adjusted_rand_score
# Max: 0.001557075126255957
# Min: 0.0014485578710689995
# AVG: 0.001459042737720425
#
# v_measure_score
# Max: 0.005504294299223301
# Min: 0.005254750862130763
# AVG: 0.005291797645836921
#
# homogeneity_score
# Max: 0.004651435454800862
# Min: 0.004443949674193731
# AVG: 0.004473389774582214
#
#
# complete
# normalized_mutual_info_score: 0.0017694775497172266
# adjusted_rand_score: 0.0006632714908984922
# v_measure_score: 0.0017694775497172266
# homogeneity_score: 0.0010458680739836375
#
# average
# normalized_mutual_info_score: 0.00427358491454357
# adjusted_rand_score: 0.0003175746391673678
# v_measure_score: 0.004273584914543569
# homogeneity_score: 0.0024173454350423355
#
# single
# normalized_mutual_info_score: 0.001977126955870458
# adjusted_rand_score: -0.00021578643926037936
# v_measure_score: 0.001977126955870458
# homogeneity_score: 0.0010021443318753963
#
# Saved
