# %%
from sklearn.datasets import fetch_20newsgroups

from gensim import corpora, models

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, v_measure_score, homogeneity_score

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
folder = "./20news_lda_lsi/"
kmeans_res_path = "kmeans_res_20News_"
hierarchy_res_path = "hierarchy_res_20News_"

tokenize_models = {
    "lda": models.LdaModel}

categories_light = ["comp.graphics", "rec.autos", "sci.med",  "talk.politics.mideast"]
categories_hard = ["talk.politics.guns", "talk.politics.mideast",  "talk.politics.misc"]
categories = {"light": categories_light, "hard": categories_hard}

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)
    
    tokens = [word.lower() for word in tokens if word.isalnum()]
    
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words ]
    
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# %%
def filter_text_by_pos(text, pos_to_keep):
    tokens = word_tokenize(text)
    tagged_tokens = pos_tag(tokens)
    
    filtered_tokens = [token for token, pos in tagged_tokens if pos in pos_to_keep]
    
    return filtered_tokens

# %%
def cluster_kmeans(matrix, metrics, true_labels, num_clusters=2, num_iterations=50):
    scores = {}
    for metric in metrics:
        scores.update({metric.__name__: []})

    # for i in tqdm(range(num_iterations), total=num_iterations, desc="Iterations"):
    for i in range(num_iterations):
        clusters = KMeans(n_clusters=num_clusters, random_state=i, n_init=5)

        clusters.fit_predict(matrix)
        
        for metric in metrics:
            score = metric(true_labels, clusters.labels_)
            scores[metric.__name__].append(score)

    kmeans_res = ""
    for metric in scores:
        kmeans_res += f"\n{metric} \nMax: {np.max(scores[metric])} \
                                    \nMin: {np.min(scores[metric])} \
                                    \nAVG: {np.mean(scores[metric])} \n"
        
    print(kmeans_res)
    return kmeans_res

# %%
def cluster_hierarchy(matrix, metrics, true_labels, num_clusters=2):
    linkages = ["complete", "average", "single"]

    hierarchy_res = ""

    if matrix.shape[0] != matrix.shape[1]:
        affinity = "euclidean"
        # matrix = matrix.toarray()
        linkages.append("ward")
    else:
        affinity = "precomputed"

    for linkage in linkages:
        hierarchy_res += f"\n{linkage}"

        agg_clustering = AgglomerativeClustering(n_clusters=num_clusters, metric=affinity, linkage=linkage)

        agg_clustering.fit_predict(matrix)

        for metric in metrics:
            score = metric(true_labels, agg_clustering.labels_)
            hierarchy_res += f"\n{metric.__name__}: {score}"
        
        hierarchy_res += "\n"
    
    print(hierarchy_res)
    return hierarchy_res

# %%
def main(dataset):
    num_topics = 10
    true_labels = dataset.target
    distances = ["none", 
                 "euclidean", 
                 "cosine"
                 ]
    metrics = [normalized_mutual_info_score, 
               adjusted_rand_score, 
               v_measure_score, 
               homogeneity_score
               ]

    kmeans_data = pd.DataFrame(columns=distances)
    hierarchy_data = pd.DataFrame(columns=distances)

    preprocessed_data = [preprocess_text(text) for text in dataset.data]
    
    n = len(preprocessed_data)
    print(n)

    noun_data = [filter_text_by_pos(text, pos_to_keep=['NN', 'NNS']) for text in preprocessed_data]
    adj_data = [filter_text_by_pos(text, pos_to_keep=['JJ', 'JJR', 'JJS']) for text in preprocessed_data]
    noun_adj_data = [filter_text_by_pos(text, pos_to_keep=['NN', 'NNS', 'JJ', 'JJR', 'JJS']) for text in preprocessed_data]

    preprocessed_data = [text.split(' ') for text in preprocessed_data]
    list_of_data = {"ALL": preprocessed_data, "NOUNS": noun_data, "ADJ": adj_data, "NOUNS and ADJ": noun_adj_data}

    for name, data in list_of_data.items():
        print("start calculate " + name)
        text_vectors = []

        dictionary = corpora.Dictionary(data)
        bow_corpus = [dictionary.doc2bow(doc) for doc in data]

        model = models.LdaModel(bow_corpus, id2word=dictionary, num_topics=num_topics, passes=15)

        for doc_bow in bow_corpus:
            document_topics = model.get_document_topics(doc_bow, minimum_probability=0.0)
            document_topic_vector = [topic_prob for _, topic_prob in document_topics]
            text_vectors.append(document_topic_vector)

        for distance in distances:
            print(distance)
            if distance == "euclidean":
                distance_matrix = euclidean_distances(text_vectors)
            elif distance == "cosine":
                distance_matrix = cosine_distances(text_vectors)
            elif distance == "none":
                distance_matrix = np.array(text_vectors)

            kmeans_data.loc[name, distance] = cluster_kmeans(distance_matrix, metrics, true_labels, num_clusters=len(dataset.target_names))

            hierarchy_data.loc[name, distance] = cluster_hierarchy(distance_matrix, metrics, true_labels, num_clusters=len(dataset.target_names))

    return kmeans_data, hierarchy_data

# %%
news_data = {}
for category in categories:
    newsgroups = fetch_20newsgroups(subset="train",
                                remove=("headers", "footers", "quotes"),
                                categories=categories[category])
    news_data.update({category: newsgroups})

# %%
for data in news_data:
    print(data)
    kmeans_data, hierarchy_data = main(news_data[data])

    kmeans_data.to_excel(folder + "lda" + "/" + kmeans_res_path + data + ".xlsx")
    hierarchy_data.to_excel(folder + "lda" + "/" + hierarchy_res_path + data + ".xlsx")
    print("Saved")
# Out:
# light
# 2336
# start calculate ALL
# none
#
# normalized_mutual_info_score
# Max: 0.16941470233894182
# Min: 0.12023325022628964
# AVG: 0.12296426142297864
#
# adjusted_rand_score
# Max: 0.13304557802323502
# Min: 0.1084912828570714
# AVG: 0.11031717932158246
#
# v_measure_score
# Max: 0.16941470233894182
# Min: 0.12023325022628964
# AVG: 0.12296426142297863
#
# homogeneity_score
# Max: 0.1598689441186702
# Min: 0.11806403583538826
# AVG: 0.12049876473146957
#
#
# complete
# normalized_mutual_info_score: 0.0810242522274157
# adjusted_rand_score: 0.06397428423937795
# v_measure_score: 0.0810242522274157
# homogeneity_score: 0.07357216014904544
#
# average
# normalized_mutual_info_score: 0.1462309859630083
# adjusted_rand_score: 0.13019063365272163
# v_measure_score: 0.14623098596300832
# homogeneity_score: 0.13368263542149547
#
# single
# normalized_mutual_info_score: 0.00251442100988
# adjusted_rand_score: -2.71593926314745e-05
# v_measure_score: 0.0025144210098799994
# homogeneity_score: 0.0012702704460406478
#
# ward
# normalized_mutual_info_score: 0.10965160302228369
# adjusted_rand_score: 0.09597328005735974
# v_measure_score: 0.10965160302228369
# homogeneity_score: 0.10626781158370245
#
# euclidean
#
# normalized_mutual_info_score
# Max: 0.09663326250410308
# Min: 0.08517431672195451
# AVG: 0.08675021089258196
#
# adjusted_rand_score
# Max: 0.08380423082628938
# Min: 0.06876783973448346
# AVG: 0.07091062235413373
#
# v_measure_score
# Max: 0.09663326250410306
# Min: 0.08517431672195451
# AVG: 0.08675021089258196
#
# homogeneity_score
# Max: 0.09416651666044067
# Min: 0.08265760510944897
# AVG: 0.08421222721548158
#
#
# complete
# normalized_mutual_info_score: 0.0810242522274157
# adjusted_rand_score: 0.06397428423937795
# v_measure_score: 0.0810242522274157
# homogeneity_score: 0.07357216014904544
#
# average
# normalized_mutual_info_score: 0.1462309859630083
# adjusted_rand_score: 0.13019063365272163
# v_measure_score: 0.14623098596300832
# homogeneity_score: 0.13368263542149547
#
# single
# normalized_mutual_info_score: 0.00251442100988
# adjusted_rand_score: -2.71593926314745e-05
# v_measure_score: 0.0025144210098799994
# homogeneity_score: 0.0012702704460406478
#
# cosine
#
# normalized_mutual_info_score
# Max: 0.13435855842800398
# Min: 0.13412845110320856
# AVG: 0.1343539562815081
#
# adjusted_rand_score
# Max: 0.13423086817241944
# Min: 0.13391795074007112
# AVG: 0.1342246098237725
#
# v_measure_score
# Max: 0.13435855842800398
# Min: 0.13412845110320856
# AVG: 0.1343539562815081
#
# homogeneity_score
# Max: 0.1341287058029155
# Min: 0.13389710045854136
# AVG: 0.134124073696028
#
#
# complete
# normalized_mutual_info_score: 0.06884407243828006
# adjusted_rand_score: 0.04564570432639339
# v_measure_score: 0.06884407243828004
# homogeneity_score: 0.059863424464376085
#
# average
# normalized_mutual_info_score: 0.13429439158311374
# adjusted_rand_score: 0.09808473642981112
# v_measure_score: 0.13429439158311376
# homogeneity_score: 0.11388796379810903
#
# single
# normalized_mutual_info_score: 0.0025440675528772575
# adjusted_rand_score: 2.7322461209621025e-07
# v_measure_score: 0.002544067552877258
# homogeneity_score: 0.0012852477021360728
#
# start calculate NOUNS
# none
#
# normalized_mutual_info_score
# Max: 0.28927263187687274
# Min: 0.22814194731688728
# AVG: 0.2780617844910105
#
# adjusted_rand_score
# Max: 0.22651699005457507
# Min: 0.1810471145516073
# AVG: 0.2177254684382598
#
# v_measure_score
# Max: 0.28927263187687274
# Min: 0.22814194731688725
# AVG: 0.2780617844910105
#
# homogeneity_score
# Max: 0.27577002820754104
# Min: 0.2128037446093988
# AVG: 0.2640696436474482
#
#
# complete
# normalized_mutual_info_score: 0.16890167475485282
# adjusted_rand_score: 0.09142884241114065
# v_measure_score: 0.16890167475485282
# homogeneity_score: 0.1410144043911738
#
# average
# normalized_mutual_info_score: 0.16521997954755305
# adjusted_rand_score: 0.09176067179738777
# v_measure_score: 0.16521997954755305
# homogeneity_score: 0.1271017557645351
#
# single
# normalized_mutual_info_score: 0.003354627852153713
# adjusted_rand_score: -3.3037810612239654e-05
# v_measure_score: 0.003354627852153713
# homogeneity_score: 0.0016947379143395901
#
# ward
# normalized_mutual_info_score: 0.23270037932846038
# adjusted_rand_score: 0.1441818718627762
# v_measure_score: 0.2327003793284604
# homogeneity_score: 0.21349480583020528
#
# euclidean
#
# normalized_mutual_info_score
# Max: 0.20531113734722553
# Min: 0.20412179998079957
# AVG: 0.20455203853371134
#
# adjusted_rand_score
# Max: 0.1433710361317708
# Min: 0.1413285083960045
# AVG: 0.14193722102992187
#
# v_measure_score
# Max: 0.20531113734722556
# Min: 0.2041217999807996
# AVG: 0.20455203853371134
#
# homogeneity_score
# Max: 0.19942143124926653
# Min: 0.19816235830039783
# AVG: 0.19860030065614548
#
#
# complete
# normalized_mutual_info_score: 0.16890167475485282
# adjusted_rand_score: 0.09142884241114065
# v_measure_score: 0.16890167475485282
# homogeneity_score: 0.1410144043911738
#
# average
# normalized_mutual_info_score: 0.16521997954755305
# adjusted_rand_score: 0.09176067179738777
# v_measure_score: 0.16521997954755305
# homogeneity_score: 0.1271017557645351
#
# single
# normalized_mutual_info_score: 0.003354627852153713
# adjusted_rand_score: -3.3037810612239654e-05
# v_measure_score: 0.003354627852153713
# homogeneity_score: 0.0016947379143395901
#
# cosine
#
# normalized_mutual_info_score
# Max: 0.30062154957196474
# Min: 0.28283088921917066
# AVG: 0.29388596681269985
#
# adjusted_rand_score
# Max: 0.2892051453554024
# Min: 0.2662187679047752
# AVG: 0.27105715417880755
#
# v_measure_score
# Max: 0.30062154957196463
# Min: 0.2828308892191707
# AVG: 0.29388596681269985
#
# homogeneity_score
# Max: 0.295158412708654
# Min: 0.27936284212937323
# AVG: 0.2873625363968679
#
#
# complete
# normalized_mutual_info_score: 0.23024018728798676
# adjusted_rand_score: 0.19763849464939837
# v_measure_score: 0.2302401872879868
# homogeneity_score: 0.20898049884993053
#
# average
# normalized_mutual_info_score: 0.22032407162315418
# adjusted_rand_score: 0.17814196701690396
# v_measure_score: 0.22032407162315418
# homogeneity_score: 0.19774006305245667
#
# single
# normalized_mutual_info_score: 0.004327798853058452
# adjusted_rand_score: 0.00012085689475811605
# v_measure_score: 0.004327798853058452
# homogeneity_score: 0.002426074505631574
#
# start calculate ADJ
# none
#
# normalized_mutual_info_score
# Max: 0.07924019389258599
# Min: 0.025110098652471585
# AVG: 0.05165297737164394
#
# adjusted_rand_score
# Max: 0.05533196993982635
# Min: 0.01411510860601676
# AVG: 0.029904734956078614
#
# v_measure_score
# Max: 0.07924019389258599
# Min: 0.025110098652471585
# AVG: 0.05165297737164394
#
# homogeneity_score
# Max: 0.07464151866161003
# Min: 0.023955495466147274
# AVG: 0.047504445887774915
#
#
# complete
# normalized_mutual_info_score: 0.07369505302660721
# adjusted_rand_score: 0.031201335430388746
# v_measure_score: 0.0736950530266072
# homogeneity_score: 0.058644944430213945
#
# average
# normalized_mutual_info_score: 0.04228399111045106
# adjusted_rand_score: 0.01013158377932801
# v_measure_score: 0.042283991110451065
# homogeneity_score: 0.032278663895252975
#
# single
# normalized_mutual_info_score: 0.0025184226021324556
# adjusted_rand_score: -2.8375386878099952e-05
# v_measure_score: 0.0025184226021324556
# homogeneity_score: 0.0012694264440796018
#
# ward
# normalized_mutual_info_score: 0.03032741173907591
# adjusted_rand_score: 0.018984085072966117
# v_measure_score: 0.030327411739075914
# homogeneity_score: 0.02741456593967243
#
# euclidean
#
# normalized_mutual_info_score
# Max: 0.04347896296865271
# Min: 0.024744101134370953
# AVG: 0.027229965991143842
#
# adjusted_rand_score
# Max: 0.02669124656922117
# Min: 0.014555918299269492
# AVG: 0.01619379343377251
#
# v_measure_score
# Max: 0.04347896296865271
# Min: 0.024744101134370956
# AVG: 0.027229965991143846
#
# homogeneity_score
# Max: 0.04074903488149082
# Min: 0.023576513824875214
# AVG: 0.025913906512584867
#
#
# complete
# normalized_mutual_info_score: 0.07369505302660721
# adjusted_rand_score: 0.031201335430388746
# v_measure_score: 0.0736950530266072
# homogeneity_score: 0.058644944430213945
#
# average
# normalized_mutual_info_score: 0.04228399111045106
# adjusted_rand_score: 0.01013158377932801
# v_measure_score: 0.042283991110451065
# homogeneity_score: 0.032278663895252975
#
# single
# normalized_mutual_info_score: 0.0025184226021324556
# adjusted_rand_score: -2.8375386878099952e-05
# v_measure_score: 0.0025184226021324556
# homogeneity_score: 0.0012694264440796018
#
# cosine
#
# normalized_mutual_info_score
# Max: 0.06347579167671043
# Min: 0.03160772384547165
# AVG: 0.045803508766624326
#
# adjusted_rand_score
# Max: 0.041096725183530754
# Min: 0.023832250962777007
# AVG: 0.03707384541022757
#
# v_measure_score
# Max: 0.06347579167671043
# Min: 0.031607723845471655
# AVG: 0.045803508766624326
#
# homogeneity_score
# Max: 0.06095957535174164
# Min: 0.03133564340963027
# AVG: 0.04414277748642182
#
#
# complete
# normalized_mutual_info_score: 0.07170882847947745
# adjusted_rand_score: 0.04728205277528619
# v_measure_score: 0.07170882847947746
# homogeneity_score: 0.06548878804810278
#
# average
# normalized_mutual_info_score: 0.03579390344971906
# adjusted_rand_score: 0.008841234038668044
# v_measure_score: 0.035793903449719056
# homogeneity_score: 0.027635330985798512
#
# single
# normalized_mutual_info_score: 0.006184082460633207
# adjusted_rand_score: 0.0006030290456124816
# v_measure_score: 0.006184082460633207
# homogeneity_score: 0.0036927383966037517
#
# start calculate NOUNS and ADJ
# none
#
# normalized_mutual_info_score
# Max: 0.3936613671017971
# Min: 0.3390797206185163
# AVG: 0.34927659910467085
#
# adjusted_rand_score
# Max: 0.3920314513665377
# Min: 0.28061494943682286
# AVG: 0.29998119695393977
#
# v_measure_score
# Max: 0.39366136710179706
# Min: 0.33907972061851627
# AVG: 0.34927659910467085
#
# homogeneity_score
# Max: 0.39087687529331117
# Min: 0.3264046408637692
# AVG: 0.3394120454287355
#
#
# complete
# normalized_mutual_info_score: 0.16975851125000868
# adjusted_rand_score: 0.10420113350918156
# v_measure_score: 0.1697585112500087
# homogeneity_score: 0.1420040892852439
#
# average
# normalized_mutual_info_score: 0.11159675298265859
# adjusted_rand_score: 0.02035134134552843
# v_measure_score: 0.1115967529826586
# homogeneity_score: 0.07838122043460297
#
# single
# normalized_mutual_info_score: 0.002528834410350642
# adjusted_rand_score: -1.858361882492356e-05
# v_measure_score: 0.002528834410350642
# homogeneity_score: 0.0012746745802230987
#
# ward
# normalized_mutual_info_score: 0.3001556011188029
# adjusted_rand_score: 0.25111955357883353
# v_measure_score: 0.3001556011188029
# homogeneity_score: 0.2924950379984859
#
# euclidean
#
# normalized_mutual_info_score
# Max: 0.25056941539669086
# Min: 0.2479490071549541
# AVG: 0.25002873975558804
#
# adjusted_rand_score
# Max: 0.1831559152540108
# Min: 0.17773069158147148
# AVG: 0.1813804750739172
#
# v_measure_score
# Max: 0.2505694153966909
# Min: 0.24794900715495413
# AVG: 0.25002873975558804
#
# homogeneity_score
# Max: 0.2443776235450005
# Min: 0.2414836106734889
# AVG: 0.2438219088226815
#
#
# complete
# normalized_mutual_info_score: 0.16975851125000868
# adjusted_rand_score: 0.10420113350918156
# v_measure_score: 0.1697585112500087
# homogeneity_score: 0.1420040892852439
#
# average
# normalized_mutual_info_score: 0.11159675298265859
# adjusted_rand_score: 0.02035134134552843
# v_measure_score: 0.1115967529826586
# homogeneity_score: 0.07838122043460297
#
# single
# normalized_mutual_info_score: 0.002528834410350642
# adjusted_rand_score: -1.858361882492356e-05
# v_measure_score: 0.002528834410350642
# homogeneity_score: 0.0012746745802230987
#
# cosine
#
# normalized_mutual_info_score
# Max: 0.37055336971649777
# Min: 0.31490277392157284
# AVG: 0.3311236903372766
#
# adjusted_rand_score
# Max: 0.37266956345817687
# Min: 0.30286913246914465
# AVG: 0.31126496932976794
#
# v_measure_score
# Max: 0.37055336971649777
# Min: 0.31490277392157284
# AVG: 0.3311236903372766
#
# homogeneity_score
# Max: 0.3687471993743979
# Min: 0.31282759185149084
# AVG: 0.3269746189584635
#
#
# complete
# normalized_mutual_info_score: 0.2712899821776284
# adjusted_rand_score: 0.2554783958032877
# v_measure_score: 0.2712899821776284
# homogeneity_score: 0.257341343044861
#
# average
# normalized_mutual_info_score: 0.32543972699925244
# adjusted_rand_score: 0.27629097350267046
# v_measure_score: 0.3254397269992524
# homogeneity_score: 0.3048117562289384
#
# single
# normalized_mutual_info_score: 0.004047036400004659
# adjusted_rand_score: 5.679201378158903e-05
# v_measure_score: 0.004047036400004659
# homogeneity_score: 0.002260526634599885
#
# Saved
# hard
# 1575
# start calculate ALL
# none
#
# normalized_mutual_info_score
# Max: 0.03477190050394778
# Min: 0.0026340286108282682
# AVG: 0.02162367468406269
#
# adjusted_rand_score
# Max: 0.025304061962155296
# Min: 0.003608094941926908
# AVG: 0.010644856726348913
#
# v_measure_score
# Max: 0.034771900503947774
# Min: 0.0026340286108282682
# AVG: 0.02162367468406269
#
# homogeneity_score
# Max: 0.03364623780792013
# Min: 0.0023005252008847237
# AVG: 0.02013978606219075
#
#
# complete
# normalized_mutual_info_score: 0.024017642758683105
# adjusted_rand_score: 0.005806737109776235
# v_measure_score: 0.024017642758683108
# homogeneity_score: 0.017792103040370356
#
# average
# normalized_mutual_info_score: 0.021557287260383157
# adjusted_rand_score: 0.002619499532335186
# v_measure_score: 0.02155728726038316
# homogeneity_score: 0.015674253807221268
#
# single
# normalized_mutual_info_score: 0.003562717757215714
# adjusted_rand_score: -0.00021335494215459982
# v_measure_score: 0.003562717757215714
# homogeneity_score: 0.0018058311308054833
#
# ward
# normalized_mutual_info_score: 0.019060447355096842
# adjusted_rand_score: 0.005170155671394214
# v_measure_score: 0.019060447355096845
# homogeneity_score: 0.017475554978052203
#
# euclidean
#
# normalized_mutual_info_score
# Max: 0.021455701510815155
# Min: 0.021350611872033128
# AVG: 0.02140131330542915
#
# adjusted_rand_score
# Max: 0.011474727092287041
# Min: 0.01140167276709762
# AVG: 0.01141873585275579
#
# v_measure_score
# Max: 0.02145570151081515
# Min: 0.02135061187203313
# AVG: 0.02140131330542915
#
# homogeneity_score
# Max: 0.02012788500770901
# Min: 0.0200063631808658
# AVG: 0.020041741719538927
#
#
# complete
# normalized_mutual_info_score: 0.024017642758683105
# adjusted_rand_score: 0.005806737109776235
# v_measure_score: 0.024017642758683108
# homogeneity_score: 0.017792103040370356
#
# average
# normalized_mutual_info_score: 0.021557287260383157
# adjusted_rand_score: 0.002619499532335186
# v_measure_score: 0.02155728726038316
# homogeneity_score: 0.015674253807221268
#
# single
# normalized_mutual_info_score: 0.003562717757215714
# adjusted_rand_score: -0.00021335494215459982
# v_measure_score: 0.003562717757215714
# homogeneity_score: 0.0018058311308054833
#
# cosine
#
# normalized_mutual_info_score
# Max: 0.021530764784629654
# Min: 0.021530764784629654
# AVG: 0.021530764784629654
#
# adjusted_rand_score
# Max: 0.013155408409522723
# Min: 0.013155408409522723
# AVG: 0.013155408409522722
#
# v_measure_score
# Max: 0.021530764784629654
# Min: 0.021530764784629654
# AVG: 0.021530764784629654
#
# homogeneity_score
# Max: 0.020629598371069674
# Min: 0.020629598371069674
# AVG: 0.02062959837106967
#
#
# complete
# normalized_mutual_info_score: 0.027429617815490148
# adjusted_rand_score: 0.006064116681583151
# v_measure_score: 0.027429617815490144
# homogeneity_score: 0.021681292417807117
#
# average
# normalized_mutual_info_score: 0.007197591855685896
# adjusted_rand_score: 0.0017036536494990926
# v_measure_score: 0.007197591855685896
# homogeneity_score: 0.006009528835442613
#
# single
# normalized_mutual_info_score: 0.0038208980512256293
# adjusted_rand_score: 7.113021922160646e-05
# v_measure_score: 0.0038208980512256293
# homogeneity_score: 0.0019366947141862727
#
# start calculate NOUNS
# none
#
# normalized_mutual_info_score
# Max: 0.04218242039358706
# Min: 0.027116902015121555
# AVG: 0.03429469102784278
#
# adjusted_rand_score
# Max: 0.03025058676042122
# Min: 0.006963376203655406
# AVG: 0.01807592507548525
#
# v_measure_score
# Max: 0.04218242039358706
# Min: 0.027116902015121555
# AVG: 0.03429469102784278
#
# homogeneity_score
# Max: 0.036317765247426206
# Min: 0.022623691540858935
# AVG: 0.02935355815289237
#
#
# complete
# normalized_mutual_info_score: 0.011418185573039526
# adjusted_rand_score: 0.0014207828315311523
# v_measure_score: 0.011418185573039526
# homogeneity_score: 0.007945837240199217
#
# average
# normalized_mutual_info_score: 0.010012997779665706
# adjusted_rand_score: 0.008109427602115422
# v_measure_score: 0.010012997779665706
# homogeneity_score: 0.007819633528740528
#
# single
# normalized_mutual_info_score: 0.0013040885207328012
# adjusted_rand_score: -0.0003705381979152044
# v_measure_score: 0.0013040885207328012
# homogeneity_score: 0.0007441894984402731
#
# ward
# normalized_mutual_info_score: 0.02465540282392015
# adjusted_rand_score: 0.021654058996096064
# v_measure_score: 0.024655402823920154
# homogeneity_score: 0.020864636589618724
#
# euclidean
#
# normalized_mutual_info_score
# Max: 0.03766817912287263
# Min: 0.019180498203020622
# AVG: 0.028022477728529
#
# adjusted_rand_score
# Max: 0.019530794553345342
# Min: 0.0047798290955155375
# AVG: 0.013427274614069878
#
# v_measure_score
# Max: 0.03766817912287263
# Min: 0.019180498203020622
# AVG: 0.028022477728529
#
# homogeneity_score
# Max: 0.03175204243845805
# Min: 0.018173269197830855
# AVG: 0.024587459495716155
#
#
# complete
# normalized_mutual_info_score: 0.011418185573039526
# adjusted_rand_score: 0.0014207828315311523
# v_measure_score: 0.011418185573039526
# homogeneity_score: 0.007945837240199217
#
# average
# normalized_mutual_info_score: 0.010012997779665706
# adjusted_rand_score: 0.008109427602115422
# v_measure_score: 0.010012997779665706
# homogeneity_score: 0.007819633528740528
#
# single
# normalized_mutual_info_score: 0.0013040885207328012
# adjusted_rand_score: -0.0003705381979152044
# v_measure_score: 0.0013040885207328012
# homogeneity_score: 0.0007441894984402731
#
# cosine
#
# normalized_mutual_info_score
# Max: 0.04323898368633128
# Min: 0.025934725446836546
# AVG: 0.0367153493061656
#
# adjusted_rand_score
# Max: 0.025306811488435905
# Min: 0.011833547100533068
# AVG: 0.016727738554079236
#
# v_measure_score
# Max: 0.04323898368633128
# Min: 0.025934725446836546
# AVG: 0.0367153493061656
#
# homogeneity_score
# Max: 0.03824696959731835
# Min: 0.022536196892602174
# AVG: 0.03252857231358522
#
#
# complete
# normalized_mutual_info_score: 0.013146885979822612
# adjusted_rand_score: 0.0018614271067171424
# v_measure_score: 0.013146885979822612
# homogeneity_score: 0.009187884168087914
#
# average
# normalized_mutual_info_score: 0.033672758787385765
# adjusted_rand_score: 0.025130099085887685
# v_measure_score: 0.03367275878738576
# homogeneity_score: 0.027723298884772783
#
# single
# normalized_mutual_info_score: 0.0018376921619266992
# adjusted_rand_score: -8.799959770526156e-05
# v_measure_score: 0.001837692161926699
# homogeneity_score: 0.0010449975925548296
#
# start calculate ADJ
# none
#
# normalized_mutual_info_score
# Max: 0.04012588107450359
# Min: 0.010963000904091046
# AVG: 0.02407616490006824
#
# adjusted_rand_score
# Max: 0.022186789350145467
# Min: 0.0019239890820020842
# AVG: 0.010673606715005182
#
# v_measure_score
# Max: 0.04012588107450361
# Min: 0.010963000904091042
# AVG: 0.02407616490006824
#
# homogeneity_score
# Max: 0.036970963985297964
# Min: 0.008992671577970495
# AVG: 0.02069443864363597
#
#
# complete
# normalized_mutual_info_score: 0.020142323985315604
# adjusted_rand_score: 0.010353181218439351
# v_measure_score: 0.020142323985315604
# homogeneity_score: 0.01692003873573239
#
# average
# normalized_mutual_info_score: 0.009360614078911596
# adjusted_rand_score: 0.0006550473075319991
# v_measure_score: 0.009360614078911594
# homogeneity_score: 0.006753136314763546
#
# single
# normalized_mutual_info_score: 0.0035296527683280404
# adjusted_rand_score: -0.00025225889584707246
# v_measure_score: 0.003529652768328041
# homogeneity_score: 0.0017890715134734154
#
# ward
# normalized_mutual_info_score: 0.02512272851521214
# adjusted_rand_score: 0.007806156517925832
# v_measure_score: 0.025122728515212144
# homogeneity_score: 0.021750756360624804
#
# euclidean
#
# normalized_mutual_info_score
# Max: 0.028148513890229356
# Min: 0.01221033329024153
# AVG: 0.01696558470383056
#
# adjusted_rand_score
# Max: 0.01333035723478926
# Min: 0.005202639348216834
# AVG: 0.007204028218681305
#
# v_measure_score
# Max: 0.028148513890229356
# Min: 0.012210333290241529
# AVG: 0.01696558470383056
#
# homogeneity_score
# Max: 0.025708008913332275
# Min: 0.011492307166240927
# AVG: 0.01562856924299463
#
#
# complete
# normalized_mutual_info_score: 0.020142323985315604
# adjusted_rand_score: 0.010353181218439351
# v_measure_score: 0.020142323985315604
# homogeneity_score: 0.01692003873573239
#
# average
# normalized_mutual_info_score: 0.009360614078911596
# adjusted_rand_score: 0.0006550473075319991
# v_measure_score: 0.009360614078911594
# homogeneity_score: 0.006753136314763546
#
# single
# normalized_mutual_info_score: 0.0035296527683280404
# adjusted_rand_score: -0.00025225889584707246
# v_measure_score: 0.003529652768328041
# homogeneity_score: 0.0017890715134734154
#
# cosine
#
# normalized_mutual_info_score
# Max: 0.031074328625588597
# Min: 0.015512310614361594
# AVG: 0.02414154076520403
#
# adjusted_rand_score
# Max: 0.017799288976030295
# Min: 0.0076804039192173885
# AVG: 0.009622118287977058
#
# v_measure_score
# Max: 0.031074328625588597
# Min: 0.015512310614361594
# AVG: 0.02414154076520403
#
# homogeneity_score
# Max: 0.02878018269362431
# Min: 0.014819441824240574
# AVG: 0.02185155803332149
#
#
# complete
# normalized_mutual_info_score: 0.021459239379762757
# adjusted_rand_score: 0.011384841250658235
# v_measure_score: 0.021459239379762757
# homogeneity_score: 0.016914564171740934
#
# average
# normalized_mutual_info_score: 0.00428822001828766
# adjusted_rand_score: 0.003690930042570419
# v_measure_score: 0.004288220018287659
# homogeneity_score: 0.0031678977357050804
#
# single
# normalized_mutual_info_score: 0.0015777660666917788
# adjusted_rand_score: -0.0003090464565590468
# v_measure_score: 0.001577766066691779
# homogeneity_score: 0.0009530063489929765
#
# start calculate NOUNS and ADJ
# none
#
# normalized_mutual_info_score
# Max: 0.11193161048177123
# Min: 0.027503975761473017
# AVG: 0.09870705121005503
#
# adjusted_rand_score
# Max: 0.12013408835154056
# Min: 0.02282230690016337
# AVG: 0.0740522293822134
#
# v_measure_score
# Max: 0.11193161048177122
# Min: 0.027503975761473013
# AVG: 0.09870705121005503
#
# homogeneity_score
# Max: 0.10461423456828114
# Min: 0.026542099994419536
# AVG: 0.09181108970451855
#
#
# complete
# normalized_mutual_info_score: 0.056250731547612634
# adjusted_rand_score: 0.03695717708219689
# v_measure_score: 0.05625073154761264
# homogeneity_score: 0.04590826312156932
#
# average
# normalized_mutual_info_score: 0.002829884819184051
# adjusted_rand_score: 0.002015176076750591
# v_measure_score: 0.0028298848191840504
# homogeneity_score: 0.0020520739471550373
#
# single
# normalized_mutual_info_score: 0.0016233488920047087
# adjusted_rand_score: -0.0002380543950499623
# v_measure_score: 0.0016233488920047087
# homogeneity_score: 0.0009166797755505261
#
# ward
# normalized_mutual_info_score: 0.08512233061260184
# adjusted_rand_score: 0.08841369735549712
# v_measure_score: 0.08512233061260183
# homogeneity_score: 0.07891935518678288
#
# euclidean
#
# normalized_mutual_info_score
# Max: 0.10590144045167667
# Min: 0.07867313640416
# AVG: 0.10048102728512256
#
# adjusted_rand_score
# Max: 0.11126673711782611
# Min: 0.03994063856326703
# AVG: 0.07290850411096175
#
# v_measure_score
# Max: 0.10590144045167667
# Min: 0.07867313640416
# AVG: 0.10048102728512259
#
# homogeneity_score
# Max: 0.10024777873507289
# Min: 0.06998999107238528
# AVG: 0.0949655558201672
#
#
# complete
# normalized_mutual_info_score: 0.056250731547612634
# adjusted_rand_score: 0.03695717708219689
# v_measure_score: 0.05625073154761264
# homogeneity_score: 0.04590826312156932
#
# average
# normalized_mutual_info_score: 0.002829884819184051
# adjusted_rand_score: 0.002015176076750591
# v_measure_score: 0.0028298848191840504
# homogeneity_score: 0.0020520739471550373
#
# single
# normalized_mutual_info_score: 0.0016233488920047087
# adjusted_rand_score: -0.0002380543950499623
# v_measure_score: 0.0016233488920047087
# homogeneity_score: 0.0009166797755505261
#
# cosine
#
# normalized_mutual_info_score
# Max: 0.11577004706525543
# Min: 0.10370832506161361
# AVG: 0.1129200175140562
#
# adjusted_rand_score
# Max: 0.11500777043847303
# Min: 0.07213450630643124
# AVG: 0.07835606796440663
#
# v_measure_score
# Max: 0.11577004706525543
# Min: 0.10370832506161361
# AVG: 0.11292001751405617
#
# homogeneity_score
# Max: 0.10991162655252722
# Min: 0.0979561847355396
# AVG: 0.10715807216906834
#
#
# complete
# normalized_mutual_info_score: 0.04572471079934754
# adjusted_rand_score: 0.024074416188629762
# v_measure_score: 0.04572471079934755
# homogeneity_score: 0.036319265517452994
#
# average
# normalized_mutual_info_score: 0.0019369296558536865
# adjusted_rand_score: 0.0004737024214607601
# v_measure_score: 0.0019369296558536865
# homogeneity_score: 0.0014205036824591645
#
# single
# normalized_mutual_info_score: 0.0014329507385982172
# adjusted_rand_score: -0.0004682196268720984
# v_measure_score: 0.0014329507385982172
# homogeneity_score: 0.0008091649108227342
#
# Saved
