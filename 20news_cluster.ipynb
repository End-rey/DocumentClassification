# %%
from sklearn.datasets import fetch_20newsgroups

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import DistanceMetric
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, v_measure_score, homogeneity_score

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag
import string
import re

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
kmeans_res_path = "kmeans_res_20News_hard.xlsx"
hierarchy_res_path = "hierarchy_res_20News_hard.xlsx"

categories = ["talk.politics.guns", "talk.politics.mideast",  "talk.politics.misc"]

# %%
vectorizer = TfidfVectorizer(max_features=5000)

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)
    
    tokens = [word.lower() for word in tokens if word.isalnum()]
    
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words ]
    
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# %%
def filter_text_by_pos(text, pos_to_keep):
    tokens = word_tokenize(text)
    tagged_tokens = pos_tag(tokens)
    
    filtered_tokens = [token for token, pos in tagged_tokens if pos in pos_to_keep]
    
    return ' '.join(filtered_tokens)

# %%
def cluster_kmeans(matrix, metrics, true_labels, num_clusters=2, num_iterations=50):
    scores = {}
    for metric in metrics:
        scores.update({metric.__name__: []})

    for i in range(num_iterations):
        clusters = KMeans(n_clusters=num_clusters, random_state=i, n_init=10)

        clusters.fit_predict(matrix)
        
        for metric in metrics:
            score = metric(true_labels, clusters.labels_)
            scores[metric.__name__].append(score)

    kmeans_res = ""
    for metric in scores:
        kmeans_res += f"\n{metric} \nMax: {np.max(scores[metric])} \
                                    \nMin: {np.min(scores[metric])} \
                                    \nAVG: {np.mean(scores[metric])} \n"
        
    print(kmeans_res)
    return kmeans_res

# %%
def cluster_hierarchy(matrix, metrics, true_labels, num_clusters=2):
    linkages = ["complete", "average", "single"]

    hierarchy_res = ""

    if matrix.shape[0] != matrix.shape[1]:
        affinity = "euclidean"
        matrix = matrix.toarray()
        linkages.append("ward")
    else:
        affinity = "precomputed"

    for linkage in linkages:
        hierarchy_res += f"\n{linkage}"

        agg_clustering = AgglomerativeClustering(n_clusters=num_clusters, metric=affinity, linkage=linkage)

        agg_clustering.fit_predict(matrix)

        for metric in metrics:
            score = metric(true_labels, agg_clustering.labels_)
            hierarchy_res += f"\n{metric.__name__}: {score}"
        
        hierarchy_res += "\n"
    
    print(hierarchy_res)
    return hierarchy_res

# %%
def main(dataset):
    true_labels = dataset.target
    distances = ["none", "euclidean", "jaccard", "cosine"]
    metrics = [normalized_mutual_info_score, adjusted_rand_score, v_measure_score, homogeneity_score]

    kmeans_data = pd.DataFrame(columns=distances)
    hierarchy_data = pd.DataFrame(columns=distances)

    preprocessed_data = [preprocess_text(text) for text in dataset.data]
    print(preprocessed_data[0])

    noun_data = [filter_text_by_pos(text, pos_to_keep=['NN', 'NNS']) for text in preprocessed_data]
    adj_data = [filter_text_by_pos(text, pos_to_keep=['JJ', 'JJR', 'JJS']) for text in preprocessed_data]
    noun_adj_data = [filter_text_by_pos(text, pos_to_keep=['NN', 'NNS', 'JJ', 'JJR', 'JJS']) for text in preprocessed_data]

    list_of_data = {"ALL": preprocessed_data, "NOUNS": noun_data, "ADJ": adj_data, "NOUNS and ADJ": noun_adj_data}

    for name, data in list_of_data.items():
        text_vectors = vectorizer.fit_transform(data)
        
        for distance in distances:
            if distance == "euclidean":
                distance_matrix = euclidean_distances(text_vectors)
            elif distance == "jaccard":
                dist = DistanceMetric.get_metric(distance)
                distance_matrix = dist.pairwise(text_vectors)
            elif distance == "cosine":
                distance_matrix = cosine_distances(text_vectors)
            elif distance == "none":
                distance_matrix = text_vectors

            kmeans_data.loc[name, distance] = cluster_kmeans(distance_matrix, metrics, true_labels, num_clusters=len(dataset.target_names))

            hierarchy_data.loc[name, distance] = cluster_hierarchy(distance_matrix, metrics, true_labels, num_clusters=len(dataset.target_names))

    return kmeans_data, hierarchy_data

# %%
newsgroups = fetch_20newsgroups(subset="train",
                                remove=("headers", "footers", "quotes"),
                                categories=categories)

# %%
kmeans_data, hierarchy_data = main(newsgroups)
# Out:
# bit unfair call blame clinton administration alone initiative underway bush administration basically bipartisan effort establishment demopublicans republicrats bipartisan effort brought l scandal bcci etc
#
# normalized_mutual_info_score
# Max: 0.2575767580781821
# Min: 0.07477041758813775
# AVG: 0.17853997716852646
#
# adjusted_rand_score
# Max: 0.11900313214863209
# Min: 0.013939403502231081
# AVG: 0.06466545561004997
#
# v_measure_score
# Max: 0.2575767580781821
# Min: 0.07477041758813775
# AVG: 0.17853997716852646
#
# homogeneity_score
# Max: 0.2065823530670431
# Min: 0.06727287868859523
# AVG: 0.1457907704522163
#
#
# complete
# normalized_mutual_info_score: 0.015575683471545494
# adjusted_rand_score: 0.01750161477345245
# v_measure_score: 0.015575683471545492
# homogeneity_score: 0.015186980515142768
#
# average
# normalized_mutual_info_score: 0.002361212243776151
# adjusted_rand_score: -0.00017075935868267689
# v_measure_score: 0.0023612122437761504
# homogeneity_score: 0.0011920518684427554
#
# single
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
# ward
# normalized_mutual_info_score: 0.22836624330098193
# adjusted_rand_score: 0.05967429918923902
# v_measure_score: 0.22836624330098196
# homogeneity_score: 0.17001550306920427
#
#
# normalized_mutual_info_score
# Max: 0.008726519194393061
# Min: 0.006924104886369169
# AVG: 0.0077889499663855695
#
# adjusted_rand_score
# Max: 0.004622426554444271
# Min: 0.003031830803614357
# AVG: 0.003624708951221679
#
# v_measure_score
# Max: 0.008726519194393063
# Min: 0.00692410488636917
# AVG: 0.0077889499663855695
#
# homogeneity_score
# Max: 0.007389679885176083
# Min: 0.005880202385983358
# AVG: 0.006603508214778622
#
#
# complete
# normalized_mutual_info_score: 0.006435706928278749
# adjusted_rand_score: 0.005775779131537063
# v_measure_score: 0.006435706928278748
# homogeneity_score: 0.005868028772188673
#
# average
# normalized_mutual_info_score: 0.002361212243776151
# adjusted_rand_score: -0.00017075935868267689
# v_measure_score: 0.0023612122437761504
# homogeneity_score: 0.0011920518684427554
#
# single
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
#
# normalized_mutual_info_score
# Max: 0.005864057672236101
# Min: 0.004637807876769599
# AVG: 0.005303272180510014
#
# adjusted_rand_score
# Max: 0.0026209081768038688
# Min: 0.001822985378228042
# AVG: 0.0022924753098073213
#
# v_measure_score
# Max: 0.005864057672236101
# Min: 0.004637807876769598
# AVG: 0.005303272180510016
#
# homogeneity_score
# Max: 0.004534677917639503
# Min: 0.0035720648358511394
# AVG: 0.0040884570335681936
#
#
# complete
# normalized_mutual_info_score: 0.0012820578146873192
# adjusted_rand_score: -8.237473860961698e-05
# v_measure_score: 0.0012820578146873192
# homogeneity_score: 0.0007439191986741795
#
# average
# normalized_mutual_info_score: 0.0007531025256419495
# adjusted_rand_score: 0.000415270095042516
# v_measure_score: 0.0007531025256419493
# homogeneity_score: 0.00045007266213623433
#
# single
# normalized_mutual_info_score: 0.003967982496613377
# adjusted_rand_score: 0.00022431453688571753
# v_measure_score: 0.003967982496613377
# homogeneity_score: 0.002011247257620426
#
#
# normalized_mutual_info_score
# Max: 0.0997083504325801
# Min: 0.0662606208038536
# AVG: 0.07232698689040756
#
# adjusted_rand_score
# Max: 0.021892511071235726
# Min: 0.007822388463516648
# AVG: 0.010302343709197333
#
# v_measure_score
# Max: 0.09970835043258008
# Min: 0.06626062080385359
# AVG: 0.07232698689040756
#
# homogeneity_score
# Max: 0.08935009875123848
# Min: 0.058529003167999444
# AVG: 0.06402886077633346
#
#
# complete
# normalized_mutual_info_score: 0.0050167887353473415
# adjusted_rand_score: 3.4328393226293365e-05
# v_measure_score: 0.005016788735347342
# homogeneity_score: 0.0025522346203672554
#
# average
# normalized_mutual_info_score: 0.0017313702641977042
# adjusted_rand_score: 0.00011231937634484241
# v_measure_score: 0.0017313702641977044
# homogeneity_score: 0.0009794084728526053
#
# single
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
#
# normalized_mutual_info_score
# Max: 0.20698421110730272
# Min: 0.0739563367594459
# AVG: 0.10888355549145924
#
# adjusted_rand_score
# Max: 0.08384912173679739
# Min: 0.00925545366419512
# AVG: 0.03262336955920671
#
# v_measure_score
# Max: 0.2069842111073027
# Min: 0.0739563367594459
# AVG: 0.10888355549145924
#
# homogeneity_score
# Max: 0.18768532299353816
# Min: 0.06421897074613185
# AVG: 0.09638288404317978
#
#
# complete
# normalized_mutual_info_score: 0.013779708855958948
# adjusted_rand_score: -0.0010703045923248214
# v_measure_score: 0.013779708855958948
# homogeneity_score: 0.009174060102228529
#
# average
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
# single
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
# ward
# normalized_mutual_info_score: 0.11025268121418558
# adjusted_rand_score: 0.000734312505593872
# v_measure_score: 0.11025268121418555
# homogeneity_score: 0.07143417301897521
#
#
# normalized_mutual_info_score
# Max: 0.012053930872211033
# Min: 0.010450751953214982
# AVG: 0.011161415185852182
#
# adjusted_rand_score
# Max: 0.006420385443499765
# Min: 0.005291733755045739
# AVG: 0.00558960474621667
#
# v_measure_score
# Max: 0.012053930872211033
# Min: 0.010450751953214984
# AVG: 0.011161415185852182
#
# homogeneity_score
# Max: 0.01019411675303967
# Min: 0.008859477732728037
# AVG: 0.009429654048499728
#
#
# complete
# normalized_mutual_info_score: 0.008463791327567307
# adjusted_rand_score: 0.00903575260555787
# v_measure_score: 0.008463791327567307
# homogeneity_score: 0.007735189268533982
#
# average
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
# single
# normalized_mutual_info_score: 0.0024358403927627944
# adjusted_rand_score: -8.328054781015773e-05
# v_measure_score: 0.0024358403927627944
# homogeneity_score: 0.0012297276956253567
#
#
# normalized_mutual_info_score
# Max: 0.006832936351753703
# Min: 0.0017598031189546015
# AVG: 0.005111950791520465
#
# adjusted_rand_score
# Max: 0.0023536697735660377
# Min: -0.0012051061372905026
# AVG: 0.0014195924654210965
#
# v_measure_score
# Max: 0.006832936351753702
# Min: 0.0017598031189546013
# AVG: 0.005111950791520465
#
# homogeneity_score
# Max: 0.004686120453616787
# Min: 0.0013099019551942833
# AVG: 0.00350593622539261
#
#
# complete
# normalized_mutual_info_score: 0.0023185643104572415
# adjusted_rand_score: 0.00010380681978233422
# v_measure_score: 0.002318564310457241
# homogeneity_score: 0.0013340148945110407
#
# average
# normalized_mutual_info_score: 0.0020017804854213423
# adjusted_rand_score: -0.00043250380526336845
# v_measure_score: 0.0020017804854213423
# homogeneity_score: 0.001272467904218764
#
# single
# normalized_mutual_info_score: 0.002361212243776151
# adjusted_rand_score: -0.00017075935868267689
# v_measure_score: 0.0023612122437761504
# homogeneity_score: 0.0011920518684427554
#
#
# normalized_mutual_info_score
# Max: 0.17105084186635555
# Min: 0.07983624267062173
# AVG: 0.15879281071874005
#
# adjusted_rand_score
# Max: 0.06774854189643939
# Min: 0.01359386102736153
# AVG: 0.05925955885854489
#
# v_measure_score
# Max: 0.17105084186635555
# Min: 0.07983624267062173
# AVG: 0.15879281071874005
#
# homogeneity_score
# Max: 0.15712449461285322
# Min: 0.07060817228739939
# AVG: 0.14530988777386267
#
#
# complete
# normalized_mutual_info_score: 0.006683854935387252
# adjusted_rand_score: 8.983114535555401e-05
# v_measure_score: 0.0066838549353872515
# homogeneity_score: 0.0034451046300169753
#
# average
# normalized_mutual_info_score: 0.002424998328137018
# adjusted_rand_score: 0.00016335126454505522
# v_measure_score: 0.0024249983281370182
# homogeneity_score: 0.001392965354240344
#
# single
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
#
# normalized_mutual_info_score
# Max: 0.20827438668026307
# Min: 0.07249196893072975
# AVG: 0.20082292673614355
#
# adjusted_rand_score
# Max: 0.04841697036752408
# Min: 0.01605596944113831
# AVG: 0.04482069927705345
#
# v_measure_score
# Max: 0.2082743866802631
# Min: 0.07249196893072975
# AVG: 0.20082292673614355
#
# homogeneity_score
# Max: 0.1527364366372096
# Min: 0.06342005864377581
# AVG: 0.14673162129640538
#
#
# complete
# normalized_mutual_info_score: 0.006646566126789212
# adjusted_rand_score: 6.101274640560691e-05
# v_measure_score: 0.006646566126789212
# homogeneity_score: 0.0055768141441479
#
# average
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
# single
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
# ward
# normalized_mutual_info_score: 0.16045803446808915
# adjusted_rand_score: 0.039203155492572105
# v_measure_score: 0.16045803446808912
# homogeneity_score: 0.11706986278002392
#
#
# normalized_mutual_info_score
# Max: 0.07691524500742701
# Min: 0.0743475868000522
# AVG: 0.07650444859714925
#
# adjusted_rand_score
# Max: 0.006303828875079575
# Min: 0.005585343199140241
# AVG: 0.006188170231106085
#
# v_measure_score
# Max: 0.07691524500742701
# Min: 0.07434758680005221
# AVG: 0.07650444859714925
#
# homogeneity_score
# Max: 0.05437545718065263
# Min: 0.052382391919701565
# AVG: 0.054056388951750495
#
#
# complete
# normalized_mutual_info_score: 0.011068180305301578
# adjusted_rand_score: 0.0066731625970150605
# v_measure_score: 0.01106818030530158
# homogeneity_score: 0.010691907929786939
#
# average
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
# single
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066
#
#
# normalized_mutual_info_score
# Max: 0.0025216886768706036
# Min: 0.0008629347977612776
# AVG: 0.0010483028014809184
#
# adjusted_rand_score
# Max: -0.00045658823404982543
# Min: -0.0014145652164944697
# AVG: -0.0006430584419605051
#
# v_measure_score
# Max: 0.002521688676870604
# Min: 0.0008629347977612776
# AVG: 0.0010483028014809184
#
# homogeneity_score
# Max: 0.0015824376961436637
# Min: 0.0005972365054639917
# AVG: 0.0007222983878504649
#
#
# complete
# normalized_mutual_info_score: 0.0005927101982559165
# adjusted_rand_score: -0.0009342384267507589
# v_measure_score: 0.0005927101982559165
# homogeneity_score: 0.0003645138458582639
#
# average
# normalized_mutual_info_score: 0.002510778633989501
# adjusted_rand_score: 0.00018999390573808987
# v_measure_score: 0.002510778633989501
# homogeneity_score: 0.0021112699248254756
#
# single
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
#
# normalized_mutual_info_score
# Max: 0.19408107175874562
# Min: 0.1923235182201654
# AVG: 0.1932853060334692
#
# adjusted_rand_score
# Max: 0.039856340728896676
# Min: 0.038864772649483056
# AVG: 0.039401090623676624
#
# v_measure_score
# Max: 0.19408107175874562
# Min: 0.19232351822016544
# AVG: 0.1932853060334692
#
# homogeneity_score
# Max: 0.14009646180975754
# Min: 0.13854112273214678
# AVG: 0.13939507270476809
#
#
# complete
# normalized_mutual_info_score: 0.001403348243034828
# adjusted_rand_score: 0.00017544397195553527
# v_measure_score: 0.0014033482430348282
# homogeneity_score: 0.0007139375722699372
#
# average
# normalized_mutual_info_score: 0.0018501558133808597
# adjusted_rand_score: -0.001035698558573638
# v_measure_score: 0.0018501558133808597
# homogeneity_score: 0.0011378240867515967
#
# single
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
#
# normalized_mutual_info_score
# Max: 0.26420571641861385
# Min: 0.07968811522144838
# AVG: 0.22080179131459976
#
# adjusted_rand_score
# Max: 0.23509182745516963
# Min: 0.01718840073508627
# AVG: 0.0788333890598263
#
# v_measure_score
# Max: 0.2642057164186138
# Min: 0.07968811522144838
# AVG: 0.2208017913145998
#
# homogeneity_score
# Max: 0.23859881554014944
# Min: 0.07174660009978513
# AVG: 0.1744260300547539
#
#
# complete
# normalized_mutual_info_score: 0.012557530856061783
# adjusted_rand_score: 0.006704194664586465
# v_measure_score: 0.012557530856061783
# homogeneity_score: 0.011860590636678207
#
# average
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
# single
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
# ward
# normalized_mutual_info_score: 0.23711313226377076
# adjusted_rand_score: 0.09080454774306326
# v_measure_score: 0.2371131322637707
# homogeneity_score: 0.1850014188200309
#
#
# normalized_mutual_info_score
# Max: 0.04684072952132915
# Min: 0.03183125789656244
# AVG: 0.03751071380413923
#
# adjusted_rand_score
# Max: 0.03748816600882167
# Min: 0.025187329254870123
# AVG: 0.03107794134350395
#
# v_measure_score
# Max: 0.046840729521329144
# Min: 0.031831257896562444
# AVG: 0.03751071380413923
#
# homogeneity_score
# Max: 0.039026748739820545
# Min: 0.02675945746762099
# AVG: 0.03153447701152641
#
#
# complete
# normalized_mutual_info_score: 0.01910739094934626
# adjusted_rand_score: 0.011549257021929937
# v_measure_score: 0.01910739094934626
# homogeneity_score: 0.01651250870222618
#
# average
# normalized_mutual_info_score: 0.0025810389376197686
# adjusted_rand_score: 6.737740424806971e-05
# v_measure_score: 0.002581038937619769
# homogeneity_score: 0.001303030803869079
#
# single
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
#
# normalized_mutual_info_score
# Max: 0.005657845109119625
# Min: 0.0008419897349122209
# AVG: 0.003983523770173786
#
# adjusted_rand_score
# Max: 0.0014548417623801507
# Min: -0.0009226038049627591
# AVG: 0.0008784748996677864
#
# v_measure_score
# Max: 0.0056578451091196255
# Min: 0.0008419897349122208
# AVG: 0.003983523770173786
#
# homogeneity_score
# Max: 0.003764323476013816
# Min: 0.000540793581372391
# AVG: 0.00270584748739923
#
#
# complete
# normalized_mutual_info_score: 0.0016687765279533176
# adjusted_rand_score: -0.0002911390242690822
# v_measure_score: 0.0016687765279533179
# homogeneity_score: 0.0009489442738847481
#
# average
# normalized_mutual_info_score: 0.0018410667004098488
# adjusted_rand_score: -0.0010476570719455036
# v_measure_score: 0.0018410667004098488
# homogeneity_score: 0.0011334027431962762
#
# single
# normalized_mutual_info_score: 0.0023964529504406757
# adjusted_rand_score: -0.0001294499202150984
# v_measure_score: 0.0023964529504406753
# homogeneity_score: 0.001209843047670891
#
#
# normalized_mutual_info_score
# Max: 0.10686710826759717
# Min: 0.07380760280418258
# AVG: 0.07762244073397034
#
# adjusted_rand_score
# Max: 0.029507935062356945
# Min: 0.012355030237467032
# AVG: 0.014725025552786824
#
# v_measure_score
# Max: 0.10686710826759718
# Min: 0.07380760280418257
# AVG: 0.07762244073397034
#
# homogeneity_score
# Max: 0.09576802736498978
# Min: 0.06544368810808406
# AVG: 0.06878505533888869
#
#
# complete
# normalized_mutual_info_score: 0.0056921843758364985
# adjusted_rand_score: 0.00011860100163062331
# v_measure_score: 0.0056921843758364985
# homogeneity_score: 0.002924908632406578
#
# average
# normalized_mutual_info_score: 0.0018895256125216458
# adjusted_rand_score: -0.00023334221312070415
# v_measure_score: 0.0018895256125216462
# homogeneity_score: 0.001072617655109253
#
# single
# normalized_mutual_info_score: 0.0026183193292056944
# adjusted_rand_score: 0.00011111680968432928
# v_measure_score: 0.0026183193292056944
# homogeneity_score: 0.001321851712732066

# %%
from IPython.display import display

display(kmeans_data.style.set_properties(**{
    'text-align': 'center',
    'white-space': 'pre-wrap',
}))
# Out:
# <style type="text/css">
# #T_adc80_row0_col0, #T_adc80_row0_col1, #T_adc80_row0_col2, #T_adc80_row0_col3, #T_adc80_row1_col0, #T_adc80_row1_col1, #T_adc80_row1_col2, #T_adc80_row1_col3, #T_adc80_row2_col0, #T_adc80_row2_col1, #T_adc80_row2_col2, #T_adc80_row2_col3, #T_adc80_row3_col0, #T_adc80_row3_col1, #T_adc80_row3_col2, #T_adc80_row3_col3 {
#   text-align: center;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_adc80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adc80_level0_col0" class="col_heading level0 col0" >none</th>
#       <th id="T_adc80_level0_col1" class="col_heading level0 col1" >euclidean</th>
#       <th id="T_adc80_level0_col2" class="col_heading level0 col2" >jaccard</th>
#       <th id="T_adc80_level0_col3" class="col_heading level0 col3" >cosine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adc80_level0_row0" class="row_heading level0 row0" >ALL</th>
#       <td id="T_adc80_row0_col0" class="data row0 col0" >
# normalized_mutual_info_score
# Max: 0.2575767580781821
# Min: 0.07477041758813775
# AVG: 0.17853997716852646
#
# adjusted_rand_score
# Max: 0.11900313214863209
# Min: 0.013939403502231081
# AVG: 0.06466545561004997
#
# v_measure_score
# Max: 0.2575767580781821
# Min: 0.07477041758813775
# AVG: 0.17853997716852646
#
# homogeneity_score
# Max: 0.2065823530670431
# Min: 0.06727287868859523
# AVG: 0.1457907704522163
# </td>
#       <td id="T_adc80_row0_col1" class="data row0 col1" >
# normalized_mutual_info_score
# Max: 0.008726519194393061
# Min: 0.006924104886369169
# AVG: 0.0077889499663855695
#
# adjusted_rand_score
# Max: 0.004622426554444271
# Min: 0.003031830803614357
# AVG: 0.003624708951221679
#
# v_measure_score
# Max: 0.008726519194393063
# Min: 0.00692410488636917
# AVG: 0.0077889499663855695
#
# homogeneity_score
# Max: 0.007389679885176083
# Min: 0.005880202385983358
# AVG: 0.006603508214778622
# </td>
#       <td id="T_adc80_row0_col2" class="data row0 col2" >
# normalized_mutual_info_score
# Max: 0.005864057672236101
# Min: 0.004637807876769599
# AVG: 0.005303272180510014
#
# adjusted_rand_score
# Max: 0.0026209081768038688
# Min: 0.001822985378228042
# AVG: 0.0022924753098073213
#
# v_measure_score
# Max: 0.005864057672236101
# Min: 0.004637807876769598
# AVG: 0.005303272180510016
#
# homogeneity_score
# Max: 0.004534677917639503
# Min: 0.0035720648358511394
# AVG: 0.0040884570335681936
# </td>
#       <td id="T_adc80_row0_col3" class="data row0 col3" >
# normalized_mutual_info_score
# Max: 0.0997083504325801
# Min: 0.0662606208038536
# AVG: 0.07232698689040756
#
# adjusted_rand_score
# Max: 0.021892511071235726
# Min: 0.007822388463516648
# AVG: 0.010302343709197333
#
# v_measure_score
# Max: 0.09970835043258008
# Min: 0.06626062080385359
# AVG: 0.07232698689040756
#
# homogeneity_score
# Max: 0.08935009875123848
# Min: 0.058529003167999444
# AVG: 0.06402886077633346
# </td>
#     </tr>
#     <tr>
#       <th id="T_adc80_level0_row1" class="row_heading level0 row1" >NOUNS</th>
#       <td id="T_adc80_row1_col0" class="data row1 col0" >
# normalized_mutual_info_score
# Max: 0.20698421110730272
# Min: 0.0739563367594459
# AVG: 0.10888355549145924
#
# adjusted_rand_score
# Max: 0.08384912173679739
# Min: 0.00925545366419512
# AVG: 0.03262336955920671
#
# v_measure_score
# Max: 0.2069842111073027
# Min: 0.0739563367594459
# AVG: 0.10888355549145924
#
# homogeneity_score
# Max: 0.18768532299353816
# Min: 0.06421897074613185
# AVG: 0.09638288404317978
# </td>
#       <td id="T_adc80_row1_col1" class="data row1 col1" >
# normalized_mutual_info_score
# Max: 0.012053930872211033
# Min: 0.010450751953214982
# AVG: 0.011161415185852182
#
# adjusted_rand_score
# Max: 0.006420385443499765
# Min: 0.005291733755045739
# AVG: 0.00558960474621667
#
# v_measure_score
# Max: 0.012053930872211033
# Min: 0.010450751953214984
# AVG: 0.011161415185852182
#
# homogeneity_score
# Max: 0.01019411675303967
# Min: 0.008859477732728037
# AVG: 0.009429654048499728
# </td>
#       <td id="T_adc80_row1_col2" class="data row1 col2" >
# normalized_mutual_info_score
# Max: 0.006832936351753703
# Min: 0.0017598031189546015
# AVG: 0.005111950791520465
#
# adjusted_rand_score
# Max: 0.0023536697735660377
# Min: -0.0012051061372905026
# AVG: 0.0014195924654210965
#
# v_measure_score
# Max: 0.006832936351753702
# Min: 0.0017598031189546013
# AVG: 0.005111950791520465
#
# homogeneity_score
# Max: 0.004686120453616787
# Min: 0.0013099019551942833
# AVG: 0.00350593622539261
# </td>
#       <td id="T_adc80_row1_col3" class="data row1 col3" >
# normalized_mutual_info_score
# Max: 0.17105084186635555
# Min: 0.07983624267062173
# AVG: 0.15879281071874005
#
# adjusted_rand_score
# Max: 0.06774854189643939
# Min: 0.01359386102736153
# AVG: 0.05925955885854489
#
# v_measure_score
# Max: 0.17105084186635555
# Min: 0.07983624267062173
# AVG: 0.15879281071874005
#
# homogeneity_score
# Max: 0.15712449461285322
# Min: 0.07060817228739939
# AVG: 0.14530988777386267
# </td>
#     </tr>
#     <tr>
#       <th id="T_adc80_level0_row2" class="row_heading level0 row2" >ADJ</th>
#       <td id="T_adc80_row2_col0" class="data row2 col0" >
# normalized_mutual_info_score
# Max: 0.20827438668026307
# Min: 0.07249196893072975
# AVG: 0.20082292673614355
#
# adjusted_rand_score
# Max: 0.04841697036752408
# Min: 0.01605596944113831
# AVG: 0.04482069927705345
#
# v_measure_score
# Max: 0.2082743866802631
# Min: 0.07249196893072975
# AVG: 0.20082292673614355
#
# homogeneity_score
# Max: 0.1527364366372096
# Min: 0.06342005864377581
# AVG: 0.14673162129640538
# </td>
#       <td id="T_adc80_row2_col1" class="dat

# %%
kmeans_data.to_excel(kmeans_res_path)
hierarchy_data.to_excel(hierarchy_res_path)
